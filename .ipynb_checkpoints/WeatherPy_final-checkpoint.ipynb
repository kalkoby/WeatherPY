# %% [markdown]
# # Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and humidity. However, it is more noticeable more cities with humditity at latitude 60-65
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 40, and 90% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres at 70 latitude, a few cities has strongest winds with at least 25 mph

# %%
#dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
from citipy import citipy
from datetime import datetime
from random import uniform
from api_keys import api_key

# %%
#create a df to lat, lon
latlng_df = pd.DataFrame()

# Create a set of random lat and lng combinations
latlng_df['lat'] = np.random.uniform(low=-90.000, high=90.000, size=1500)
latlng_df['lng'] = np.random.uniform(low=-180.000, high=180.000, size=1500)

# %%
latlng_df.head()
# Out:
#          lat         lng
# 0 -66.666368 -173.769243
# 1   9.025768  -18.890645
# 2 -26.995824  128.510881
# 3 -89.134859  -99.363007
# 4  10.542133  -71.587302

# %% [markdown]
# # Generate Cities List

# %%
# # Identify nearest city for each lat, lng combination and country 
# just in case there may be multiple same city name but at different locations.
cities = []
countries = []

for index, row in latlng_df.iterrows():    
    city = citipy.nearest_city(row['lat'],row['lng'])
    cities.append(city.city_name)
    countries.append(city.country_code)
 
 
    
latlng_df['City'] = cities
latlng_df['Country'] = countries

# %%
len(latlng_df)
latlng_df = latlng_df.drop_duplicates(['City','Country'])
len(latlng_df)
# Out:
# 624

# %%
latlng_df.head()
cities_list = latlng_df.drop_duplicates(["City","Country"]).reset_index()

# %%
cities_list.count()
# Out:
# index      624
# lat        624
# lng        624
# City       624
# Country    624
# dtype: int64

# %% [markdown]
# # Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it's being processed (with the city number and city name).

# %%
city_data = []

temp = []
max_temp = []
humidity = []
clouds = []
winds = []
countries = []
city_name = []
city_lat = []
city_lng = []

counter = 0
base_url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = base_url + "appid=" + api_key + "&units=" + units + "&q="

for index, row in cities_list.iterrows():
    counter += 1
    city = row["City"]  
    
  
    
    response = requests.get(query_url + city).json()
    searchCityID = response.get("id")
        
    if response.get("id"):
        temp.append(response['main']['temp']) 
        max_temp.append(response['main']['temp_max'])
        city_name.append(response["name"])
        city_lat.append(response['coord']["lat"])
        city_lng.append(response['coord']["lon"])
        countries.append(response["sys"]["country"])
        clouds.append(response["clouds"]["all"])
        humidity.append(response["main"]["humidity"])
        winds.append(response["wind"]["speed"])
       
        print(f"Processing Record {counter}  | {city}")
       
    else:
        print(f"City not found. Skipping... | {city}")
# Out:
# Processing Record 1  | vaini
# Processing Record 2  | bubaque
# Processing Record 3  | yulara
# Processing Record 4  | punta arenas
# Processing Record 5  | santa rita
# Processing Record 6  | atuona
# Processing Record 7  | bowen
# City not found. Skipping... | camana
# Processing Record 9  | gasa
# Processing Record 10  | nyurba
# Processing Record 11  | talnakh
# City not found. Skipping... | bengkulu
# City not found. Skipping... | attawapiskat
# Processing Record 14  | hobart
# Processing Record 15  | pacific grove
# Processing Record 16  | hun
# Processing Record 17  | albany
# Processing Record 18  | anchorage
# Processing Record 19  | arraial do cabo
# Processing Record 20  | ribeira grande
# Processing Record 21  | busselton
# City not found. Skipping... | brasileia
# Processing Record 23  | san jeronimo
# Processing Record 24  | ushuaia
# Processing Record 25  | castro
# Processing Record 26  | bestobe
# Processing Record 27  | hambantota
# Processing Record 28  | kapaa
# Processing Record 29  | diego de almagro
# Processing Record 30  | swan hill
# Processing Record 31  | semirom
# Processing Record 32  | bacungan
# Processing Record 33  | lhokseumawe
# Processing Record 34  | mendi
# Processing Record 35  | qaanaaq
# Processing Record 36  | bondo
# Processing Record 37  | mataura
# Processing Record 38  | hermanus
# Processing Record 39  | leningradskiy
# Processing Record 40  | saint-philippe
# Processing Record 41  | butaritari
# Processing Record 42  | savannah bight
# Processing Record 43  | nizwa
# Processing Record 44  | hofn
# Processing Record 45  | sipe sipe
# Processing Record 46  | bilma
# Processing Record 47  | batemans bay
# Processing Record 48  | mogadishu
# Processing Record 49  | fortuna
# Processing Record 50  | provideniya
# Processing Record 51  | solnechnyy
# City not found. Skipping... | palasa
# Processing Record 53  | bluff
# Processing Record 54  | eyl
# City not found. Skipping... | ciras
# Processing Record 56  | cidreira
# City not found. Skipping... | kembe
# Processing Record 58  | nisia floresta
# Processing Record 59  | san francisco
# Processing Record 60  | port alfred
# Processing Record 61  | saint-louis
# City not found. Skipping... | illoqqortoormiut
# Processing Record 63  | hithadhoo
# Processing Record 64  | constitucion
# Processing Record 65  | veraval
# Processing Record 66  | east london
# Processing Record 67  | san cristobal
# Processing Record 68  | port moresby
# City not found. Skipping... | grand river south east
# Processing Record 70  | ponta do sol
# Processing Record 71  | ekhabi
# Processing Record 72  | puerto ayora
# City not found. Skipping... | nizhneyansk
# Processing Record 74  | isangel
# Processing Record 75  | svetlogorsk
# Processing Record 76  | tirumullaivasal
# Processing Record 77  | saint george
# Processing Record 78  | beringovskiy
# Processing Record 79  | bonfim
# Processing Record 80  | taraclia
# Processing Record 81  | ocampo
# Processing Record 82  | rikitea
# Processing Record 83  | rio gallegos
# Processing Record 84  | la grande
# Processing Record 85  | cape town
# Processing Record 86  | victoria
# Processing Record 87  | severo-kurilsk
# Processing Record 88  | tuktoyaktuk
# Processing Record 89  | jamestown
# Processing Record 90  | opuwo
# Processing Record 91  | opaka
# Processing Record 92  | saldanha
# Processing Record 93  | roald
# Processing Record 94  | meulaboh
# Processing Record 95  | klaksvik
# Processing Record 96  | taoudenni
# Processing Record 97  | new norfolk
# Processing Record 98  | kitimat
# Processing Record 99  | namatanai
# Processing Record 100  | plaza de caisan
# Processing Record 101  | port blair
# Processing Record 102  | tasiilaq
# Processing Record 103  | laizhou
# Processing Record 104  | yellowknife
# Processing Record 105  | jalu
# City not found. Skipping... | belushya guba
# Processing Record 107  | geraldton
# Processing Record 108  | mildura
# Processing Record 109  | ossora
# Processing Record 110  | skopin
# Processing Record 111  | oistins
# Processing Record 112  | henties bay
# Processing Record 113  | pucallpa
# Processing Record 114  | plouzane
# Processing Record 115  | dali
# Processing Record 116  | macia
# Processing Record 117  | port hardy
# Processing Record 118  | tingi
# Processing Record 119  | katsuura
# Processing Record 120  | saskylakh
# Processing Record 121  | saint-augustin
# Processing Record 122  | saint-jerome
# Processing Record 123  | north branch
# Processing Record 124  | bathsheba
# Processing Record 125  | kodiak
# Processing Record 126  | esperance
# Processing Record 127  | port macquarie
# Processing Record 128  | kemin
# Processing Record 129  | alekseyevsk
# Processing Record 130  | katunino
# Processing Record 131  | lufkin
# Processing Record 132  | srednekolymsk
# City not found. Skipping... | opobo
# Processing Record 134  | bethel
# Processing Record 135  | kruisfontein
# Processing Record 136  | lebu
# Processing Record 137  | kysyl-syr
# City not found. Skipping... | barentsburg
# City not found. Skipping... | halalo
# Processing Record 140  | ulagan
# City not found. Skipping... | tsihombe
# Processing Record 142  | ilulissat
# Processing Record 143  | padang
# Processing Record 144  | vila franca do campo
# Processing Record 145  | yar-sale
# Processing Record 146  | sorland
# Processing Record 147  | alice town
# Processing Record 148  | makakilo city
# City not found. Skipping... | amderma
# Processing Record 150  | tilichiki
# Processing Record 151  | faanui
# City not found. Skipping... | malwan
# Processing Record 153  | lasa
# Processing Record 154  | preobrazheniye
# Processing Record 155  | cherskiy
# Processing Record 156  | angermunde
# Processing Record 157  | havoysund
# Processing Record 158  | tomatlan
# Processing Record 159  | pochutla
# Processing Record 160  | berezovyy
# Processing Record 161  | katobu
# Processing Record 162  | port elizabeth
# Processing Record 163  | koumac
# Processing Record 164  | severo-yeniseyskiy
# City not found. Skipping... | rudbar
# Processing Record 166  | santa maria
# Processing Record 167  | lorengau
# Processing Record 168  | chumikan
# Processing Record 169  | kabare
# Processing Record 170  | barrow
# Processing Record 171  | bonavista
# Processing Record 172  | shenjiamen
# Processing Record 173  | san blas
# Processing Record 174  | chokurdakh
# Processing Record 175  | ahipara
# Processing Record 176  | goma
# Processing Record 177  | vostok
# Processing Record 178  | georgetown
# Processing Record 179  | turukhansk
# Processing Record 180  | sao filipe
# Processing Record 181  | hilo
# Processing Record 182  | praia
# Processing Record 183  | dhadar
# Processing Record 184  | bambous virieux
# Processing Record 185  | sola
# Processing Record 186  | hasaki
# Processing Record 187  | novyy urengoy
# Processing Record 188  | tuatapere
# Processing Record 189  | pisco
# City not found. Skipping... | taolanaro
# Processing Record 191  | cayenne
# Processing Record 192  | caboolture
# Processing Record 193  | zhezkazgan
# Processing Record 194  | nalut
# Processing Record 195  | nikolskoye
# Processing Record 196  | tadine
# City not found. Skipping... | gurgan
# Processing Record 198  | san andres
# Processing Record 199  | doba
# Processing Record 200  | tiksi
# Processing Record 201  | huinan
# Processing Record 202  | vanimo
# Processing Record 203  | nome
# Processing Record 204  | upernavik
# Processing Record 205  | honiara
# Processing Record 206  | tessalit
# Processing Record 207  | ucluelet
# Processing Record 208  | biswan
# Processing Record 209  | vargem grande
# Processing Record 210  | kungurtug
# City not found. Skipping... | asau
# Processing Record 212  | alta floresta
# Processing Record 213  | dikson
# Processing Record 214  | shingu
# Processing Record 215  | bredasdorp
# Processing Record 216  | tevaitoa
# Processing Record 217  | obo
# Processing Record 218  | baijiantan
# City not found. Skipping... | toftir
# Processing Record 220  | pekan
# City not found. Skipping... | ruatoria
# Processing Record 222  | nkhotakota
# Processing Record 223  | shahrud
# Processing Record 224  | mount gambier
# Processing Record 225  | ola
# Processing Record 226  | guerrero negro
# Processing Record 227  | margate
# Processing Record 228  | lulea
# Processing Record 229  | cockburn town
# Processing Record 230  | fare
# Processing Record 231  | bud
# Processing Record 232  | luderitz
# Processing Record 233  | el cobre
# Processing Record 234  | emerald
# Processing Record 235  | marovoay
# Processing Record 236  | nivala
# Processing Record 237  | wanning
# Processing Record 238  | tosya
# Processing Record 239  | kuusamo
# Processing Record 240  | vallenar
# Processing Record 241  | san patricio
# Processing Record 242  | mar del plata
# Processing Record 243  | cabra
# Processing Record 244  | paita
# Processing Record 245  | lagoa
# Processing Record 246  | kuznechnoye
# Processing Record 247  | poya
# Processing Record 248  | adrar
# Processing Record 249  | matagami
# Processing Record 250  | avarua
# Processing Record 251  | sangamner
# Processing Record 252  | karratha
# Processing Record 253  | cap malheureux
# Processing Record 254  | itarema
# Processing Record 255  | plettenberg bay
# Processing Record 256  | garowe
# Processing Record 257  | ajaccio
# Processing Record 258  | wynyard
# Processing Record 259  | laguna
# Processing Record 260  | san rafael del sur
# Processing Record 261  | cleveland
# Processing Record 262  | kaitangata
# Processing Record 263  | pimentel
# Processing Record 264  | umm kaddadah
# Processing Record 265  | rybnaya sloboda
# Processing Record 266  | aklavik
# Processing Record 267  | mpanda
# Processing Record 268  | khatanga
# Processing Record 269  | cork
# Processing Record 270  | lockhart
# Processing Record 271  | madison
# City not found. Skipping... | krasnoselkup
# Processing Record 273  | sawtell
# Processing Record 274  | berlevag
# Processing Record 275  | manaus
# Processing Record 276  | provost
# Processing Record 277  | fez
# Processing Record 278  | hualmay
# Processing Record 279  | mayo
# Processing Record 280  | karonga
# Processing Record 281  | komatipoort
# Processing Record 282  | gaomi
# City not found. Skipping... | lar gerd
# Processing Record 284  | iqaluit
# Processing Record 285  | adelanto
# Processing Record 286  | nanakuli
# City not found. Skipping... | marcona
# Processing Record 288  | glossop
# Processing Record 289  | poum
# Processing Record 290  | olga
# Processing Record 291  | norman wells
# Processing Record 292  | farafangana
# Processing Record 293  | tazovskiy
# Processing Record 294  | monastyrshchina
# Processing Record 295  | port victoria
# Processing Record 296  | mahebourg
# Processing Record 297  | dicabisagan
# Processing Record 298  | zhanaozen
# Processing Record 299  | sinnamary
# Processing Record 300  | westport
# Processing Record 301  | longyearbyen
# Processing Record 302  | antofagasta
# Processing Record 303  | lompoc
# Processing Record 304  | hay river
# Processing Record 305  | zhigansk
# Processing Record 306  | tucuman
# Processing Record 307  | caravelas
# Processing Record 308  | tateyama
# City not found. Skipping... | mys shmidta
# Processing Record 310  | souillac
# Processing Record 311  | ginda
# City not found. Skipping... | umzimvubu
# Processing Record 313  | ouango
# Processing Record 314  | faya
# City not found. Skipping... | warqla
# Processing Record 316  | claremore
# Processing Record 317  | zilair
# Processing Record 318  | haines junction
# Processing Record 319  | havelock
# Processing Record 320  | sadasivpet
# Processing Record 321  | busayra
# Processing Record 322  | pevek
# Processing Record 323  | san vicente
# Processing Record 324  | oranjemund
# Processing Record 325  | vardo
# Processing Record 326  | quatre cocos
# Processing Record 327  | phibun mangsahan
# Processing Record 328  | ketchikan
# Processing Record 329  | sabzevar
# Processing Record 330  | ust-nera
# Processing Record 331  | la ronge
# Processing Record 332  | mocuba
# Processing Record 333  | coxim
# Processing Record 334  | hovd
# Processing Record 335  | bilibino
# Processing Record 336  | bella vista
# Processing Record 337  | teacapan
# Processing Record 338  | patti
# Processing Record 339  | hit
# Processing Record 340  | carnarvon
# Processing Record 341  | chara
# Processing Record 342  | husavik
# Processing Record 343  | zhangye
# Processing Record 344  | sitka
# Processing Record 345  | natchez
# Processing Record 346  | muros
# Processing Record 347  | macenta
# Processing Record 348  | bording
# Processing Record 349  | acaponeta
# Processing Record 350  | erzin
# City not found. Skipping... | tasbuget
# Processing Record 352  | kirakira
# Processing Record 353  | qaqortoq
# Processing Record 354  | marathon
# Processing Record 355  | tezu
# City not found. Skipping... | lolua
# Processing Record 357  | laramie
# Processing Record 358  | vossevangen
# Processing Record 359  | guarapuava
# Processing Record 360  | ridgecrest
# City not found. Skipping... | samusu
# Processing Record 362  | aykhal
# Processing Record 363  | qinzhou
# Processing Record 364  | tombouctou
# Processing Record 365  | general roca
# Processing Record 366  | airai
# Processing Record 367  | lufilufi
# City not found. Skipping... | meyungs
# Processing Record 369  | kavaratti
# Processing Record 370  | hoquiam
# Processing Record 371  | jammalamadugu
# Processing Record 372  | inhambane
# Processing Record 373  | teguise
# Processing Record 374  | touros
# Processing Record 375  | vesyegonsk
# Processing Record 376  | port hedland
# Processing Record 377  | port lincoln
# Processing Record 378  | daru
# Processing Record 379  | canon city
# Processing Record 380  | ancud
# City not found. Skipping... | burica
# Processing Record 382  | namibe
# Processing Record 383  | uyuni
# Processing Record 384  | chifeng
# Processing Record 385  | muisne
# Processing Record 386  | lincoln
# Processing Record 387  | turayf
# Processing Record 388  | kirkenaer
# City not found. Skipping... | vaitupu
# Processing Record 390  | hue
# City not found. Skipping... | zhanatas
# City not found. Skipping... | ituni
# Processing Record 393  | kloulklubed
# Processing Record 394  | rocha
# Processing Record 395  | rio brilhante
# Processing Record 396  | shelburne
# Processing Record 397  | vanavara
# Processing Record 398  | langsa
# Processing Record 399  | mehamn
# Processing Record 400  | pindiga
# City not found. Skipping... | sofiysk
# Processing Record 402  | yerbogachen
# Processing Record 403  | hervey bay
# Processing Record 404  | chuy
# Processing Record 405  | three hills
# Processing Record 406  | kot samaba
# Processing Record 407  | necochea
# Processing Record 408  | zheshart
# Processing Record 409  | lavrentiya
# Processing Record 410  | manokwari
# Processing Record 411  | talara
# Processing Record 412  | nsoko
# Processing Record 413  | cabedelo
# Processing Record 414  | mandurah
# Processing Record 415  | kenora
# Processing Record 416  | san policarpo
# Processing Record 417  | gatesville
# Processing Record 418  | ypsonas
# Processing Record 419  | aquiraz
# City not found. Skipping... | raga
# Processing Record 421  | ixtapa
# Processing Record 422  | nurota
# Processing Record 423  | dawlatabad
# Processing Record 424  | komsomolskiy
# Processing Record 425  | campagna
# Processing Record 426  | mexico
# City not found. Skipping... | sentyabrskiy
# Processing Record 428  | irbit
# Processing Record 429  | det udom
# Processing Record 430  | te anau
# Processing Record 431  | torbay
# Processing Record 432  | belyy yar
# Processing Record 433  | half moon bay

# %%
weather_data = pd.DataFrame({ "City" : city_name,
                              "Country": countries,
                              "lat": city_lat,
                              "lng": city_lng,
                              "Temp": temp,
                              "Max Temp": max_temp,
                              "humidity": humidity,                             
                              "Cloudiness": clouds,
                              "Wind Speed": winds })

# %%
#column order
weather_data = weather_data[["City","Country","lat","lng","Temp","Max Temp","humidity","Cloudiness","Wind Speed"]]
weather_data.head()

# %%
weather_data.to_csv("weather.csv",encoding="utf-8",index=False)

# %% [markdown]
# # Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["lat"],weather_data["Max Temp"],marker="o",edgecolor="black")

plt.title("City Latitude vs. Max Temperature (04/21/18)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Max_Temp_vs_Latitude_plots.png")
plt.show()

# %% [markdown]
# # Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["lat"],weather_data["humidity"],marker="o",edgecolor="black")

plt.title("City Latitude vs. Humidity (04/21/18)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.ylim(0,100)

plt.savefig("Humidity_vs_Latitude_plots.png")
plt.show()

# %% [markdown]
# # Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["lat"],weather_data["Cloudiness"],marker="o",edgecolor="black")

plt.title("City Latitude vs. Cloudiness (04/21/18)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

plt.ylim(0,100)

plt.savefig("Cloudiness_vs_Latitude_plots.png")
plt.show()

# %% [markdown]
# # Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["lat"],weather_data["Wind Speed"],marker="o",edgecolor="black")

plt.title("City Latitude vs. Wind Speed (04/21/18)")
plt.ylabel("Wind Speed (mpg)")
plt.xlabel("Latitude")
plt.grid(True)

#plt.ylim(0,30)

plt.savefig("WindSpeed_vs_Latitude_plots.png")
plt.show()
